# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import torch as pt
import math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset/sign_mnist_train.csv")
df.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %%
# Show unique labels
print(df['label'].unique())

# Count each label
print(df['label'].value_counts())
# Out:
# [ 3  6  2 13 16  8 22 18 10 20 17 19 21 23 24  1 12 11 15  4  0  5  7 14]
# label
# 17    1294
# 16    1279
# 11    1241
# 22    1225
# 5     1204
# 18    1199
# 3     1196
# 14    1196
# 19    1186
# 23    1164
# 8     1162
# 20    1161
# 13    1151
# 2     1144
# 0     1126
# 24    1118
# 10    1114
# 6     1090
# 15    1088
# 21    1082
# 12    1055
# 7     1013
# 1     1010
# 4      957
# Name: count, dtype: int64

# %%
X_train = df[1:]
y_train = df[:1]
print(X_train.shape, y_train.shape)
# Out:
# (27454, 785) (1, 785)

# %%
# Load dataset
df = pd.read_csv("dataset/sign_mnist_train.csv")  # Replace with your actual path

# Get last 5 samples
last_5 = df.tail(5)

# Prepare figure
plt.figure(figsize=(15, 3))  # Wider because it's 5 images in one row

# Loop through and plot each image
for i, (idx, row) in enumerate(last_5.iterrows()):
    label = row['label']
    pixels = row.drop('label').values.astype(np.uint8)
    
    pixel_count = len(pixels)
    side_length = int(math.sqrt(pixel_count))

    if side_length * side_length != pixel_count:
        print(f"Skipping row {idx} – pixel count {pixel_count} is not a perfect square.")
        continue

    image = pixels.reshape(side_length, side_length)

    # Plot image in a grid
    plt.subplot(1, 5, i + 1)
    plt.imshow(image, cmap='gray', vmin=0, vmax=255)
    plt.title(f"Label: {label}")
    plt.axis('off')

plt.tight_layout()
plt.show()
